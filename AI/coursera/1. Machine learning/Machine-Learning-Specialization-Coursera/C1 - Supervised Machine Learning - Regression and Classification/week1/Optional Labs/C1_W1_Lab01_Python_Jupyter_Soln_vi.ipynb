# %% [markdown]
# # Giới thiệu tóm tắt về Python và Jupyter Notebook
# Chào mừng bạn đến với lab đầu tiên!
# Các lab có sẵn để:
# - Cung cấp thông tin - như notebook này
# - Củng cố tài liệu bài giảng bằng các ví dụ thực hành
# - Cung cấp các ví dụ hoạt động về các thói quen được sử dụng trong các lab được phân loại

# %% [markdown]
# ## target
# Trong lab này, bạn sẽ:
# - Giới thiệu ngắn gọn về Jupyter notebook
# - Tham quan Jupyter notebook
# - Tìm hiểu sự khác biệt giữa markdown ô và code cells
# - Luyện tập một số python cơ bản

# %% [markdown]
# Cách dễ nhất để làm quen với Jupyter notebook là tham khảo phần tham quan có sẵn ở trên trong menu Help:

# %% [markdown]
# <figure>
#     <center> <img src="./images/C1W1L1_Tour.PNG"  alt='missing' width="400"  ><center/>
# <figure>

# %% [markdown]
# Jupyter notebook có hai loại ô được sử dụng trong khóa học này. Các ô như thế này chứa tài liệu có tên `Markdown Cells`. Tên này bắt nguồn từ ngôn ngữ định dạng đơn giản được sử dụng trong các ô. Bạn sẽ không bắt buộc phải tạo ô markdown. Sẽ rất hữu ích khi hiểu `cell pulldown` được hiển thị trong hình bên dưới. Đôi khi, một ô sẽ ở chế độ sai và bạn có thể cần khôi phục nó về trạng thái phù hợp:

# %% [markdown]
# <figure>
#    <img src="./images/C1W1L1_Markdown.PNG"  alt='missing' width="400"  >
# <figure/>

# %% [markdown]
# Loại ô còn lại là `code cell` nơi bạn sẽ viết code của mình:

# %%
# Đây là ô 'Code'
print("This is code cell")
# Out:
# This is code cell

# %% [markdown]
# ## Python
# Bạn có thể viết code của mình trong code cells.
# Để chạy code, hãy chọn ô và
# - Giữ phím shift và nhấn 'enter' hoặc 'return'
# - Nhấp vào mũi tên 'run' ở trên
# <figure>
#     <img src="./images/C1W1L1_Run.PNG"  width="400"  >
# <figure/>

# %% [markdown]
# ### Câu lệnh print
# Các câu lệnh print thường sẽ sử dụng kiểu python f-string.
# Hãy thử tạo print của riêng bạn trong ô sau.
# Hãy thử cả hai phương pháp chạy ô.

# %%
# Câu lệnh print
variable = "right in the strings!"
print(f"f strings allow you to embed variables {variable}")
# Out:
# f strings allow you to embed variables right in the strings!

# %% [markdown]
# # Chúc mừng!
# Bây giờ bạn đã biết cách tìm đường xung quanh Jupyter Notebook.
