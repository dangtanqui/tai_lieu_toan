# %% [markdown]
# # Optional Lab: Giới thiệu sơ lược về Notebook Python và Jupyter
# Chào mừng bạn đến với optional lab đầu tiên!
# Các lab tùy chọn có sẵn để:
# - cung cấp thông tin - như cuốn sổ này
# - củng cố tài liệu bài giảng bằng các ví dụ thực hành
# - cung cấp các ví dụ hoạt động về các thói quen được sử dụng trong các lab được phân loại

# %% [markdown]
# ## Mục tiêu
# Trong lab này, bạn sẽ:
# - Giới thiệu ngắn gọn về máy tính xách tay Jupyter
# - Tham quan notebook Jupyter
# - Tìm hiểu sự khác biệt giữa ô markdown và ô code
# - Luyện tập một số python cơ bản

# %% [markdown]
# Cách dễ nhất để làm quen với notebook Jupyter là tham gia chuyến tham quan có sẵn ở trên trong menu Trợ giúp:

# %% [markdown]
# <figure>
#     <center> <img src="./images/C1W1L1_Tour.PNG"  alt='missing' width="400"  ><center/>
# <figure/>

# %% [markdown]
# Notebook Jupyter có hai loại ô được sử dụng trong khóa học này. Các ô như thế này chứa tài liệu có tên `Markdown Cells`. Tên này bắt nguồn từ ngôn ngữ định dạng đơn giản được sử dụng trong các ô. Bạn sẽ không bắt buộc phải sản xuất các ô markdown. Thật hữu ích khi hiểu `cell pulldown` được hiển thị trong hình bên dưới. Đôi khi, một ô sẽ ở chế độ sai và bạn có thể cần khôi phục nó về trạng thái phù hợp:

# %% [markdown]
# <figure>
#    <img src="./images/C1W1L1_Markdown.PNG"  alt='missing' width="400"  >
# <figure/>

# %% [markdown]
# Loại ô còn lại là `code cell` nơi bạn sẽ viết code của chúng ta:

# %%
# Đây là ô 'Mã'print("This is  code cell")
# Out:
# This is  code cell

# %% [markdown]
# ## Python
# Bạn có thể viết code của chúng ta vào các ô code.
# Để chạy code, hãy chọn ô và
# - giữ phím shift và nhấn 'enter' hoặc 'return'
# - nhấp vào mũi tên 'chạy' ở trên
# <figure>
#     <img src="./images/C1W1L1_Run.PNG"  width="400"  >
# <figure/>

# %% [markdown]
# ### In báo cáo
# Các câu lệnh in thường sẽ sử dụng kiểu python f-string.
# Hãy thử tạo bản in của riêng bạn trong ô sau.
# Hãy thử cả hai phương pháp chạy ô.

# %%
# in báo cáovariable = "right in the strings!"
print(f"f strings allow you to embed variables {variable}")
# Out:
# f strings allow you to embed variables right in the strings!

# %% [markdown]
# # Congratulations!
# Bây giờ bạn đã biết cách tìm đường xung quanh Notebook Jupyter.
