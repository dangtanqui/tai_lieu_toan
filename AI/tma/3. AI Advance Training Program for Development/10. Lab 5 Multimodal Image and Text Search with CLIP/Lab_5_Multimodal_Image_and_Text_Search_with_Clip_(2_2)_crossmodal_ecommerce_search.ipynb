# %% [markdown]
# # 🔎 Use CLIP to search product photos using text or image
#
# Have you ever had a wonderful pair of shoes that were just getting worn out, and you wanted to find another similar pair? Sometimes it's tough to know exactly what words to use.
#
# [Amazon has a feature that lets you snap a picture and find similar items in their store](https://www.hunker.com/13771848/amazon-photo-search). That's great for Jeff Bezos, but not so good if you have your own ecommerce store and want that feature.
#
# So in this notebook we're going to build a simple search engine that will let you **use images (or text) to search through a catalog of fashion items**.
#
# In later notebooks we'll flesh it out with endpoints (for remote access), scaling, fine-tuning and cloud deployment. But for now let's keep it dead simple.
#
# You can find a fuller version of this example [here](https://examples.jina.ai/fashion?utm_source=notebook-ecommerce-1).
#
# ## 📑 Our dataset
#
# We're using a small subset of the [Kaggle Fashion Product Images (small) dataset](https://www.kaggle.com/paramaggarwal/fashion-product-images-small). The full dataset (while still small) is less practical to get into our notebook environment.
#
# It consists of
#
# - A CSV file that contains image ids and metadata
# - 770 low-res color photos of fashion items like so:
#
# |  |  | |
# | --- | --- | --- |
# | ![](https://github.com/jina-ai/example-multimodal-fashion-search/blob/main/data/subset/10001.jpg?raw=true) | ![](https://github.com/jina-ai/example-multimodal-fashion-search/blob/main/data/subset/10008.jpg?raw=true) | ![](https://github.com/jina-ai/example-multimodal-fashion-search/blob/main/data/subset/10009.jpg?raw=true) |
#
# ## 🤖 Our tech stack
#
# ### DocArray
#
# We'll use [DocArray](https://docarray.jina.ai?utm_source=notebook-ecommerce-1) to convert our CSV file and images into Documents that we can then search through.
#
# DocArray is a good fit for this, since whatever kind of data we use (text or image in our case), we only need to think about one data format: A Document can contain pretty much anything. We can also use DocArray to [bulk apply]() processing on our images, which is much faster than messing around with for-loops.
#
# We can also use it to [push our dataset to the cloud](https://docarray.jina.ai/fundamentals/documentarray/serialization/#from-to-cloud?utm_source=notebook-ecommerce-1), making it easier to use it later in other notebooks.
#
# ### CLIP-as-service
#
# We'll use CLIP-as-service to quickly generate [vector embeddings](https://docarray.jina.ai/fundamentals/document/embedding?utm_source=notebook-ecommerce-1) for our images, and thus be able to perform nearest-neighbor search using text or images as input.
#
# CLIP-as-service is a good match for this, since it requires minimal dependencies and has pretty low-latency. It's also free to use via Jina's cloud servers.
#
# ## 💬 Talk to us!
#
# Want to find out more about neural search and the Jina AI ecosystem? Join us on [Slack](https://slack.jina.ai?utm_source=notebook-ecommerce-1)!
#
# ## 📝 Notes
#
# - This is just part one in a multi-part series, where we'll use the Jina ecosystem to build an advanced text/image search engine for products.

# %% [markdown]
# ## Downloading and processing our data
#
# This is just some rough and ready code to download a toy dataset and unzip it to our `data` directory:

# %%
data_dir = "/content/data"

# %%
# !rm -rf /content/data

# %%
import os

if not os.path.isdir(data_dir):
  os.makedirs(data_dir)

  os.chdir(data_dir)
  # !wget -q https://github.com/jina-ai/example-multimodal-fashion-search/raw/main/data/subset/fashion_subset.csv
  # !wget -q https://github.com/jina-ai/example-multimodal-fashion-search/raw/main/data/subset/fashion_subset.zip
  # !unzip -qq fashion_subset.zip
  print("Downloaded!")
else:
  print("Data dir already exists, skipping download!")

os.chdir("/content")
# Out:
# Downloaded!

# %% [markdown]
# Let's take a quick look at our CSV to see what kind of data we have:

# %%
# !head -n 3 data/fashion_subset.csv
# Out:
# id,gender,masterCategory,subCategory,articleType,baseColour,season,year,usage,productDisplayName
# 10268,Men,Footwear,Shoes,Formal Shoes,Black,Fall,2012,Formal,Clarks Men Hang Work Leather Black Formal Shoes
# 10866,Men,Apparel,Topwear,Tshirts,Red,Fall,2011,Casual,Wrangler Men Motor Rider Red T-Shirts

# %% [markdown]
# ## Creating Documents
#
# Every piece of data we work with in the [Jina ecosystem](https://github.com/jina-ai?utm_source=notebook-ecommerce-1) has to be in the form of a [Document](https://docarray.jina.ai/fundamentals/document?utm_source=notebook-ecommerce-1) or [DocumentArray](https://docarray.jina.ai/fundamentals/documentarray?utm_source=notebook-ecommerce-1). This means that whether we're dealing with text, images, audio, or whatever, we only have one data format to keep in mind.
#
# Instead of manually creating all of our Documents we can simply load them from a CSV file with the [`from_csv()` method](https://docarray.jina.ai/datatypes/tabular?utm_source=notebook-ecommerce-1):

# %%
# !pip install -qqq docarray==0.21

# %%
from docarray import DocumentArray

# %%
docs = DocumentArray.from_csv("./data/fashion_subset.csv")

# %% [markdown]
# Let's see what a DocumentArray looks like:

# %%
docs.summary()
# Out:
# ╭─────────────── Documents Summary ────────────────╮
# │                                                  │
# │   Type                   DocumentArrayInMemory   │
# │   Length                 770                     │
# │   Homogenous Documents   True                    │
# │   Common Attributes      ('id', 'tags')          │
# │   Multimodal dataclass   False                   │
# │                                                  │
# ╰──────────────────────────────────────────────────╯
# ╭───────────────────── Attributes Summary ─────────────────────╮
# │                                                              │
# │   Attribute   Data type   #Unique values   Has empty value   │
# │  ──────────────────────────────────────────────────────────  │
# │   id          ('str',)    770              False             │
# │   tags        ('dict',)   770              False             │
# │                                                              │
# ╰──────────────────────────────────────────────────────────────╯

# %% [markdown]
# As we can see, all Documents have `id` and `tags`.
#
# And now we can dig into how an individual Document looks:

# %%
docs[0]
# Out:
# 📄 Document: 10268
# ╭───────────┬──────────────────────────────────────────────────────────────────╮
# │ Attribute │ Value                                                            │
# ├───────────┼──────────────────────────────────────────────────────────────────┤
# │ tags      │ {'season': 'Fall', 'usage': 'Formal', 'baseColour': 'Black',     │
# │           │ 'subCategory': 'Shoes', 'gender': 'Men', 'year': '2012',         │
# │           │ 'masterCategory': 'Footwear', 'articleType': 'Formal Shoes',     │
# │           │ 'productDisplayName': 'Clarks Men Hang Work Leather Black Formal │
# │           │ Shoes'}                                                          │
# ╰───────────┴──────────────────────────────────────────────────────────────────╯

# %%
from IPython.display import display, Image
display(Image(filename=f'{data_dir}/{docs[0].id}.jpg'))

# %% [markdown]
# As we can see, the Document's tags (metadata) were brought in directly from the CSV file.
#
# Where are the images though? Because we only took data from the CSV (which doesn't *directly* specify where the images are), we'll have to create a URI for each image under `doc.uri`.
#
# Luckily the URI is based on the `id` column of the CSV, which was mapped to `doc.id`:

# %%
for doc in docs:
  doc.uri = f"{data_dir}/{doc.id}.jpg"

# %% [markdown]
# Because we're dealing with images, we'll need to:
#
# - Load the URI to an image tensor (so we have something to feed into our encoder later)
# - Resize all the images to a consistent size
# - Ensure all the tensors are in the same format
#
# We can do this in a function and then call `docs.apply(process_images)`

# %%
def process_images(doc):
  return doc.load_uri_to_image_tensor().set_image_tensor_shape((80, 60))

# %%
docs.apply(process_images, show_progress=True)
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭─────────────────────────── Documents Summary ───────────────────────────╮
# │                                                                         │
# │   Type                   DocumentArrayInMemory                          │
# │   Length                 770                                            │
# │   Homogenous Documents   True                                           │
# │   Common Attributes      ('id', 'tensor', 'mime_type', 'uri', 'tags')   │
# │   Multimodal dataclass   False                                          │
# │                                                                         │
# ╰─────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────── Attributes Summary ───────────────────────╮
# │                                                                 │
# │   Attribute   Data type      #Unique values   Has empty value   │
# │  ─────────────────────────────────────────────────────────────  │
# │   id          ('str',)       770              False             │
# │   mime_type   ('str',)       1                False             │
# │   tags        ('dict',)      770              False             │
# │   tensor      ('ndarray',)   770              False             │
# │   uri         ('str',)       770              False             │
# │                                                                 │
# ╰─────────────────────────────────────────────────────────────────╯

# %% [markdown]
# Great, now we can see each Document has an image tensor.
#
# We can see what we've got with the `plot_image_sprites()` method:

# %%
docs.plot_image_sprites()

# %% [markdown]
# Let's also normalize them for consistency (we could have done this earlier, but then the plotting doesn't look so good). There's a nice explanation of normalization [here](https://inside-machinelearning.com/en/why-and-how-to-normalize-data-object-detection-on-image-in-pytorch-part-1/#Normalizing_data)

# %%
for doc in docs:
  doc.set_image_tensor_normalization()

# %% [markdown]
# ## Generating embeddings
#
# Now we've loaded our images, we can feed them into our encoder. In our cases we want to encode using the [CLIP model](https://openai.com/blog/clip?utm_source=notebook-ecommerce-1), so we can use [CLIP-as-service](https://clip-as-service.jina.ai/) since it's low-latency and simple to use.
#
# Why is CLIP a good encoder for this? CLIP encodes both text and images to a common vector space, which means we can use text to search images, images to search text, images to search images, etc.
#
# In our search engine we'll focus on:
#
# - Image-to-image
# - Text-to-image
#
# ---
#
# ❓ Want to learn more about CLIP? Check out notebook for [finetuning CLIP with anime datasets](https://colab.research.google.com/drive/189LHTpYaefMhKNIGOzTLHHavlgmoIWg9?usp=sharing)
#
# ---

# %%
# !pip install -qqq urllib3>=2 grpcio>=1.71.0
# !pip install clip-client clip_server
# Out:
# Requirement already satisfied: clip-client in /usr/local/lib/python3.11/dist-packages (0.8.3)
# Requirement already satisfied: clip_server in /usr/local/lib/python3.11/dist-packages (0.8.3)
# Requirement already satisfied: jina>=3.12.0 in /usr/local/lib/python3.11/dist-packages (from clip-client) (3.27.20)
# Requirement already satisfied: docarray<0.30.0,>=0.19.0 in /usr/local/lib/python3.11/dist-packages (from docarray[common]<0.30.0,>=0.19.0->clip-client) (0.21.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from clip-client) (24.2)
# Requirement already satisfied: ftfy in /usr/local/lib/python3.11/dist-packages (from clip_server) (6.3.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from clip_server) (2.6.0+cu124)
# Requirement already satisfied: regex in /usr/local/lib/python3.11/dist-packages (from clip_server) (2024.11.6)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (from clip_server) (0.21.0+cu124)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.11/dist-packages (from clip_server) (0.22.1)
# Requirement already satisfied: open-clip-torch<2.9.0,>=2.8.0 in /usr/local/lib/python3.11/dist-packages (from clip_server) (2.8.2)
# Requirement already satisfied: pillow-avif-plugin in /usr/local/lib/python3.11/dist-packages (from clip_server) (1.5.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from docarray<0.30.0,>=0.19.0->docarray[common]<0.30.0,>=0.19.0->clip-client) (2.0.2)
# Requirement already satisfied: rich>=12.0.0 in /usr/local/lib/python3.11/dist-packages (from docarray<0.30.0,>=0.19.0->docarray[common]<0.30.0,>=0.19.0->clip-client) (13.9.4)
# Requirement already satisfied: jina-hubble-sdk>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from docarray<0.30.0,>=0.19.0->docarray[common]<0.30.0,>=0.19.0->clip-client) (0.39.0)
# Requirement already satisfied: protobuf>=3.13.0 in /usr/local/lib/python3.11/dist-packages (from docarray[common]<0.30.0,>=0.19.0->clip-client) (3.20.3)
# Requirement already satisfied: lz4 in /usr/local/lib/python3.11/dist-packages (from docarray[common]<0.30.0,>=0.19.0->clip-client) (4.4.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from docarray[common]<0.30.0,>=0.19.0->clip-client) (2.32.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from docarray[common]<0.30.0,>=0.19.0->clip-client) (3.10.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from docarray[common]<0.30.0,>=0.19.0->clip-client) (11.2.1)
# Requirement already satisfied: fastapi in /usr/local/lib/python3.11/dist-packages (from docarray[common]<0.30.0,>=0.19.0->clip-client) (0.115.12)
# Requirement already satisfied: pydantic>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from docarray[common]<0.30.0,>=0.19.0->clip-client) (1.10.22)
# Requirement already satisfied: uvicorn in /usr/local/lib/python3.11/dist-packages (from docarray[common]<0.30.0,>=0.19.0->clip-client) (0.23.1)
# Requirement already satisfied: opentelemetry-api>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from jina>=3.12.0->clip-client) (1.19.0)
# Requirement already satisfied: grpcio<=1.57.0,>=1.46.0 in /usr/local/lib/python3.11/dist-packages (from jina>=3.12.0->clip-client) (1.57.0)
# Requirement already satisfied: opentelemetry-exporter-prometheus>=0.33b0 in /usr/local/lib/python3.11/dist-packages (from jina>=3.12.0->clip-client) (0.41b0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from jina>=3.12.0->clip-client) (6.0.2)
# Requirement already satisfied: aiofiles in /usr/local/lib/python3.11/dist-packages (from jina>=3.12.0->clip-client) (24.1.0)
# Requirement already satisfied: opentelemetry-sdk<1.20.0,>=1.14.0 in /usr/local/lib/python3.11/dist-packages (from jina>=3.12.0->clip-client) (1.19.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.13.0 in /usr/local/lib/python3.11/dist-packages (from jina>=3.12.0->clip-client) (1.19.0)
# Requirement already satisfied: opentelemetry-exporter-otlp>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from jina>=3.12.0->clip-client) (1.19.0)
# Requirement already satisfied: jcloud>=0.0.35 in /usr/local/lib/python3.11/dist-packages (from jina>=3.12.0->clip-client) (0.3)
# Requirement already satisfied: pathspec in /usr/local/lib/python3.11/dist-packages (from jina>=3.12.0->clip-client) (0.12.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from jina>=3.12.0->clip-client) (3.11.15)
# Requirement already satisfied: grpcio-reflection<=1.57.0,>=1.46.0 in /usr/local/lib/python3.11/dist-packages (from jina>=3.12.0->clip-client) (1.48.2)
# Requirement already satisfied: urllib3<2.0.0,>=1.25.9 in /usr/local/lib/python3.11/dist-packages (from jina>=3.12.0->clip-client) (1.26.20)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from jina>=3.12.0->clip-client) (3.18.0)
# Requirement already satisfied: python-multipart in /usr/local/lib/python3.11/dist-packages (from jina>=3.12.0->clip-client) (0.0.20)
# Requirement already satisfied: grpcio-health-checking<=1.57.0,>=1.46.0 in /usr/local/lib/python3.11/dist-packages (from jina>=3.12.0->clip-client) (1.48.2)
# Requirement already satisfied: opentelemetry-instrumentation-aiohttp-client>=0.33b0 in /usr/local/lib/python3.11/dist-packages (from jina>=3.12.0->clip-client) (0.40b0)
# Requirement already satisfied: websockets in /usr/local/lib/python3.11/dist-packages (from jina>=3.12.0->clip-client) (15.0.1)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.33b0 in /usr/local/lib/python3.11/dist-packages (from jina>=3.12.0->clip-client) (0.40b0)
# Requirement already satisfied: docker in /usr/local/lib/python3.11/dist-packages (from jina>=3.12.0->clip-client) (7.1.0)
# Requirement already satisfied: opentelemetry-instrumentation-grpc>=0.35b0 in /usr/local/lib/python3.11/dist-packages (from jina>=3.12.0->clip-client) (0.40b0)
# Requirement already satisfied: uvloop in /usr/local/lib/python3.11/dist-packages (from jina>=3.12.0->clip-client) (0.21.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from open-clip-torch<2.9.0,>=2.8.0->clip_server) (4.67.1)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.11/dist-packages (from open-clip-torch<2.9.0,>=2.8.0->clip_server) (0.32.4)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.11/dist-packages (from open-clip-torch<2.9.0,>=2.8.0->clip_server) (0.2.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch->clip_server) (4.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch->clip_server) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch->clip_server) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch->clip_server) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->clip_server) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->clip_server) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->clip_server) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch->clip_server) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch->clip_server) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch->clip_server) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch->clip_server) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch->clip_server) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch->clip_server) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch->clip_server) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch->clip_server) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->clip_server) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->clip_server) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch->clip_server) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch->clip_server) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch->clip_server) (1.3.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from ftfy->clip_server) (0.2.13)
# Requirement already satisfied: starlette<0.47.0,>=0.40.0 in /usr/local/lib/python3.11/dist-packages (from fastapi->docarray[common]<0.30.0,>=0.19.0->clip-client) (0.46.2)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.11/dist-packages (from jcloud>=0.0.35->jina>=3.12.0->clip-client) (1.1.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.11/dist-packages (from jcloud>=0.0.35->jina>=3.12.0->clip-client) (2.9.0.post0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->jina>=3.12.0->clip-client) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->jina>=3.12.0->clip-client) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->jina>=3.12.0->clip-client) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->jina>=3.12.0->clip-client) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->jina>=3.12.0->clip-client) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->jina>=3.12.0->clip-client) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->jina>=3.12.0->clip-client) (1.20.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.11/dist-packages (from jina-hubble-sdk>=0.24.0->docarray<0.30.0,>=0.19.0->docarray[common]<0.30.0,>=0.19.0->clip-client) (6.11.0)
# Requirement already satisfied: python-jose in /usr/local/lib/python3.11/dist-packages (from jina-hubble-sdk>=0.24.0->docarray<0.30.0,>=0.19.0->docarray[common]<0.30.0,>=0.19.0->clip-client) (3.5.0)
# Requirement already satisfied: deprecated>=1.2.6 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-api>=1.12.0->jina>=3.12.0->clip-client) (1.2.18)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http==1.19.0 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-exporter-otlp>=1.12.0->jina>=3.12.0->clip-client) (1.19.0)
# Requirement already satisfied: backoff<3.0.0,>=1.10.0 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.13.0->jina>=3.12.0->clip-client) (2.2.1)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.13.0->jina>=3.12.0->clip-client) (1.70.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.19.0 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.13.0->jina>=3.12.0->clip-client) (1.19.0)
# Requirement already satisfied: opentelemetry-proto==1.19.0 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.13.0->jina>=3.12.0->clip-client) (1.19.0)
# Requirement already satisfied: opentelemetry-instrumentation==0.40b0 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-instrumentation-aiohttp-client>=0.33b0->jina>=3.12.0->clip-client) (0.40b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.40b0 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-instrumentation-aiohttp-client>=0.33b0->jina>=3.12.0->clip-client) (0.40b0)
# Requirement already satisfied: opentelemetry-util-http==0.40b0 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-instrumentation-aiohttp-client>=0.33b0->jina>=3.12.0->clip-client) (0.40b0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-instrumentation-aiohttp-client>=0.33b0->jina>=3.12.0->clip-client) (1.17.2)
# Requirement already satisfied: setuptools>=16.0 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-instrumentation==0.40b0->opentelemetry-instrumentation-aiohttp-client>=0.33b0->jina>=3.12.0->clip-client) (75.2.0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.40b0 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-instrumentation-fastapi>=0.33b0->jina>=3.12.0->clip-client) (0.40b0)
# Requirement already satisfied: asgiref~=3.0 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-instrumentation-asgi==0.40b0->opentelemetry-instrumentation-fastapi>=0.33b0->jina>=3.12.0->clip-client) (3.8.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->docarray[common]<0.30.0,>=0.19.0->clip-client) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->docarray[common]<0.30.0,>=0.19.0->clip-client) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->docarray[common]<0.30.0,>=0.19.0->clip-client) (2025.4.26)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=12.0.0->docarray<0.30.0,>=0.19.0->docarray[common]<0.30.0,>=0.19.0->clip-client) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=12.0.0->docarray<0.30.0,>=0.19.0->docarray[common]<0.30.0,>=0.19.0->clip-client) (2.19.1)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.11/dist-packages (from uvicorn->docarray[common]<0.30.0,>=0.19.0->clip-client) (8.2.1)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.11/dist-packages (from uvicorn->docarray[common]<0.30.0,>=0.19.0->clip-client) (0.16.0)
# Requirement already satisfied: httptools>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from uvicorn[standard]<=0.23.1->jina>=3.12.0->clip-client) (0.6.4)
# Requirement already satisfied: watchfiles>=0.13 in /usr/local/lib/python3.11/dist-packages (from uvicorn[standard]<=0.23.1->jina>=3.12.0->clip-client) (1.0.5)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub->open-clip-torch<2.9.0,>=2.8.0->clip_server) (1.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch->clip_server) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->docarray[common]<0.30.0,>=0.19.0->clip-client) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->docarray[common]<0.30.0,>=0.19.0->clip-client) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->docarray[common]<0.30.0,>=0.19.0->clip-client) (4.58.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->docarray[common]<0.30.0,>=0.19.0->clip-client) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->docarray[common]<0.30.0,>=0.19.0->clip-client) (3.2.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata->jina-hubble-sdk>=0.24.0->docarray<0.30.0,>=0.19.0->docarray[common]<0.30.0,>=0.19.0->clip-client) (3.22.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=12.0.0->docarray<0.30.0,>=0.19.0->docarray[common]<0.30.0,>=0.19.0->clip-client) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil->jcloud>=0.0.35->jina>=3.12.0->clip-client) (1.17.0)
# Requirement already satisfied: anyio<5,>=3.6.2 in /usr/local/lib/python3.11/dist-packages (from starlette<0.47.0,>=0.40.0->fastapi->docarray[common]<0.30.0,>=0.19.0->clip-client) (4.9.0)
# Requirement already satisfied: ecdsa!=0.15 in /usr/local/lib/python3.11/dist-packages (from python-jose->jina-hubble-sdk>=0.24.0->docarray<0.30.0,>=0.19.0->docarray[common]<0.30.0,>=0.19.0->clip-client) (0.19.1)
# Requirement already satisfied: rsa!=4.1.1,!=4.4,<5.0,>=4.0 in /usr/local/lib/python3.11/dist-packages (from python-jose->jina-hubble-sdk>=0.24.0->docarray<0.30.0,>=0.19.0->docarray[common]<0.30.0,>=0.19.0->clip-client) (4.9.1)
# Requirement already satisfied: pyasn1>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from python-jose->jina-hubble-sdk>=0.24.0->docarray<0.30.0,>=0.19.0->docarray[common]<0.30.0,>=0.19.0->clip-client) (0.6.1)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.6.2->starlette<0.47.0,>=0.40.0->fastapi->docarray[common]<0.30.0,>=0.19.0->clip-client) (1.3.1)

# %% [markdown]
# Now we just need to set the client and encode all of our Documents. We can do this for free with Jina's CLIP-as-service server!

# %%
# start clip server. More details: https://clip-as-service.jina.ai/user-guides/server/
import clip_server
# !nohup python -m clip_server > output.log 2>&1 &
#!python -m clip_server

# %%
from clip_client import Client

c = Client('grpc://0.0.0.0:51000')
docs = c.encode(docs)
c.profile()
# Out:
#  Roundtrip  13ms  100%
# ├──  Client-server network  8ms  62%
# └──  Server  5ms  38%
#     ├──  Gateway-CLIP network  1ms  20%
#     └──  CLIP model  4ms  80%
# {'Roundtrip': 13.087449000067863,
#  'Client-server network': 8.087449000067863,
#  'Server': 5,
#  'Gateway-CLIP network': 1,
#  'CLIP model': 4}

# %% [markdown]
# ---
#
# 💡 The embeddings we just generated were from a pre-trained general purpose CLIP model. That model is good for fashion products, teapots, faces, puppies, and lots of other things.
#
# For more accurate search results we'll finetune our model specifically for our fashion dataset in a future notebook. Or you can check the [finetuning CLIP for anime](https://colab.research.google.com/drive/189LHTpYaefMhKNIGOzTLHHavlgmoIWg9?usp=sharing) if you want to learn how to do that now.
#
# ---

# %% [markdown]
# ## Visualizing our data
#
# Let's [plot out our data into a 3D graph](https://docarray.jina.ai/fundamentals/documentarray/visualization/#embedding-projector?utm_source=notebook-ecommerce-1) so we can better see how embeddings are clustered.
#
# Note: You'll need to manually interrupt the cell below when you're done by hitting the "stop" button. Otherwise it will block the rest of the notebook from running.

# %%
docs.plot_embeddings(image_sprites=True)

# %% [markdown]
# We can see that different types of item are in different clusters: the watches are all together, the bags are all together and so on.
#
# You may also notice that there are two groups of shirts - those with people wearing them, and those where it's just the shirt in shot. In a later notebook we'll finetune the CLIP model so all T-shirts are closer together (i.e. ignoring the humans who we don't care about in this context)

# %% [markdown]
# ## Pushing our data to the cloud
#
# Jina allows free cloud hosting of DocumentArrays. Since we plan to use the same DocumentArray in later notebooks, let's [push it to the cloud](https://docarray.jina.ai/fundamentals/documentarray/serialization/?highlight=push%20pull#from-to-cloud?utm_source=notebook-ecommerce-1):

# %%
# docs.push("770-fashion-small-with-clip-embeddings", show_progress=True)

# %% [markdown]
# ## Search by image
#
# Let's choose one random image from our DocumentArray and use that to search for similar images in the dataset:

# %%
image_query = docs.sample(1)
image_matches = docs.find(image_query)

# %% [markdown]
# Now let's see the results. The first image will be the query image and subsequent will be matches in order of similarity.
#
# ---
#
# ⚠️ Because we only have a limited dataset, you may not always get something *super* similar. In the [example with the full dataset](https://examples.jina.ai/fashion?utm_source=notebook-ecommerce-1) you'll get better matches.
#
# ---

# %%
docs.sample(1)
# Out:
# ╭──────────────────────────────── Documents Summary ─────────────────────────────────╮
# │                                                                                    │
# │   Type                   DocumentArrayInMemory                                     │
# │   Length                 1                                                         │
# │   Homogenous Documents   True                                                      │
# │   Common Attributes      ('id', 'blob', 'mime_type', 'uri', 'tags', 'embedding')   │
# │   Multimodal dataclass   False                                                     │
# │                                                                                    │
# ╰────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────── Attributes Summary ───────────────────────╮
# │                                                                 │
# │   Attribute   Data type      #Unique values   Has empty value   │
# │  ─────────────────────────────────────────────────────────────  │
# │   blob        ('bytes',)     1                False             │
# │   embedding   ('ndarray',)   1                False             │
# │   id          ('str',)       1                False             │
# │   mime_type   ('str',)       1                False             │
# │   tags        ('dict',)      1                False             │
# │   uri         ('str',)       1                False             │
# │                                                                 │
# ╰─────────────────────────────────────────────────────────────────╯

# %%
from IPython.display import display, Image
display(Image(filename=f'{data_dir}/{image_query[0].id}.jpg'))

# %%
image_matches[0].plot_image_sprites()

# %% [markdown]
# ## Search by text
#
# As before, we're dealing with [Documents](https://docarray.jina.ai/fundamentals/document?utm_source=notebook-ecommerce-1) and [DocumentArrays](https://docarray.jina.ai/fundamentals/documentarray?utm_source=notebook-ecommerce-1). So the text query we search with should also be wrapped in a Document.

# %%
query_string = "women's red t-shirt"

from docarray import Document

text_query = DocumentArray([Document(text=query_string)])

# %% [markdown]
# Unlike our previous image search, we'll need to encode our query Document this time (since last time our query Document had already been encoded).

# %%
text_query = c.encode(text_query)

# %%
text_matches = docs.find(text_query)

# %%
text_matches[0].plot_image_sprites()

# %%
for match in text_matches[0]:
  print(f"Similarity score: {match.scores['cosine'].value}")
# Out:
# Similarity score: 0.6631284356117249
# Similarity score: 0.6795809268951416
# Similarity score: 0.6902607083320618
# Similarity score: 0.6963909864425659
# Similarity score: 0.700045108795166
# Similarity score: 0.7018143534660339
# Similarity score: 0.7027649879455566
# Similarity score: 0.7038533687591553
# Similarity score: 0.7038763761520386
# Similarity score: 0.7038989663124084
# Similarity score: 0.7062208652496338
# Similarity score: 0.7063894271850586
# Similarity score: 0.7069432735443115
# Similarity score: 0.7069432735443115
# Similarity score: 0.707099199295044
# Similarity score: 0.7074553370475769
# Similarity score: 0.7075787782669067
# Similarity score: 0.7078585624694824
# Similarity score: 0.7111999988555908
# Similarity score: 0.7139831781387329

# %% [markdown]
# Not bad for a small dataset and pre-trained (un-finetuned) model!

# %% [markdown]
# ## 🎁 Wrapping up
#
# Great - we've built a simple search engine in our notebook, with very few lines of code. But what's next?
#
# In future notebooks we'll see how you can:
#
# - [Finetune](https://finetuner.jina.ai?utm_source=notebook-ecommerce-1) the CLIP model for better results on your dataset.
# - Store your data on disk, spin up replicas/shards, start serving your search engine via a RESTful or gRPC gateway.
# - Use pre-existing [building blocks](https://hub.jina.ai?utm_source=notebook-ecommerce-1) to speed up development.
# - Host and deploy your search engine on [Jina Cloud](https://docs.jina.ai/fundamentals/jcloud?utm_source=notebook-ecommerce-1).
#
# Stay tuned to [the Jina AI blog](https://medium.com/jina-ai) or join our [Slack community](https://slack.jina.ai?utm_source=notebook-ecommerce-1) to keep up-to-date.

# %% [markdown]
# ## 📚 Learn more
#
# Want to dig more into the Jina ecosystem? Here are some resources:
#
# - [Developer portal](https://learn.jina.ai?utm_source=notebook-ecommerce-1) - tutorials, courses, videos on using Jina
# - [Fashion search notebook](https://colab.research.google.com/github/alexcg1/neural-search-notebooks/blob/main/fashion-search/1_build_basic_search/basic_search.ipynb) - build an image-to-image fashion search engine
# - [DALL-E Flow](https://colab.research.google.com/github/jina-ai/dalle-flow/blob/main/client.ipynb)/[Disco Art](https://colab.research.google.com/github/jina-ai/discoart/blob/main/discoart.ipynb) - create AI-generated art in your browser
