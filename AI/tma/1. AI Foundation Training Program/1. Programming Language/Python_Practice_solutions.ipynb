# %% [markdown]
# # 1. Basic

# %%
# Run this cell
import math

# %% [markdown]
# ## 1.1 Number and Operator

# %% [markdown]
# Use below cell to calculate these expressions:
#
# $$ a = 1 + \sqrt{2}$$
#
# $$ b = \sin(0.7) + \cos(0.2)$$
#
# $$ c = \frac{1}{5} + 3i$$
#
# Hint: you can use `math.sqrt()` method to calculate the square root of a number, and `complex()` method to create a complex number

# %%
a = 1 + math.sqrt(2)
b = math.sin(0.7) + math.cos(0.2)
c = complex(1/5, 3)
print(a, b, c)
# Out:
# 2.414213562373095 1.6242842650789326 (0.2+3j)

# %% [markdown]
# ## 1.2. String

# %% [markdown]
# Given two strings:
#
# `str1 = "Hello World, "`
#
# `str2 = "Python!"`
#
# Replace "..." in below cells to do the following requirements.

# %%
# Run this cell without modifying anything
str1 = "Hello World, "
str2 = "Python!"

# %% [markdown]
# **Use `str1` and `str2` to make a string: "Hello World, my name is Python!"**

# %%
# TO DO
str3 = str1 + "my name is " + str2
str3
# Out:
# 'Hello World, my name is Python!'

# %% [markdown]
# **Use slicing trick to get string "Hello" from `str1`**

# %%
# TO DO
str4 = str1[:5]
str4
# Out:
# 'Hello'

# %% [markdown]
# **Change the word "Python" in `str3` to your name using `replace()` method**

# %%
# TO DO
str4 = str3.replace('Python', 'TMA Solutions')
str4
# Out:
# 'Hello World, my name is TMA Solutions!'

# %% [markdown]
# ## 1.3. Array

# %% [markdown]
# Create a **list** `fruits` with 4 elements: `"apple"`, `"banana"`, `"coconut"`, `"mango"`

# %%
fruits = ['apple', 'banana', 'coconut', 'mango']
fruits
# Out:
# ['apple', 'banana', 'coconut', 'mango']

# %% [markdown]
# Check length of created list to make sure it has exactly 4 elements using `len()` method

# %%
len(fruits)
# Out:
# 4

# %% [markdown]
# Add 1 more fruit to list: `"papaya"` using `append()` method

# %%
fruits.append('papaya')
fruits
# Out:
# ['apple', 'banana', 'coconut', 'mango', 'papaya']

# %% [markdown]
# Remove element `"coconut"` using `remove()` method

# %% [markdown]
# Change the second element to `"lemon"`

# %%
fruits[1] = 'lemon'
fruits
# Out:
# ['apple', 'lemon', 'coconut', 'mango', 'papaya']

# %% [markdown]
# So, you see that **list** can change the values of element itself. But **tuple** cannot. Try it...

# %%
# Run this cell without modifying anything
my_tuple = ("1", "2", "4")
my_tuple[0] = 3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_518567/156983062.py in <module>
#       1 # Run this cell without modifying anything
#       2 my_tuple = ("1", "2", "4")
# ----> 3 my_tuple[0] = 3
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# The cell above will raise an error because a tuple is an immutable type, signifying that the value of a tuple cannot be altered once it is declared.

# %% [markdown]
# ## 1.4. Dictionary

# %% [markdown]
# - Create a dictionary contain the information of a person include:
# ```
# Name: Bobby
# Age: 25
# Job: Teacher
# Married: Yes
# ```

# %%
person = {
    'Name': 'Bobby',
    'Age': 25,
    'Job': 'Teacher',
    'Married': 'Yes'
}
person
# Out:
# {'Name': 'Bobby', 'Age': 25, 'Job': 'Teacher', 'Married': 'Yes'}

# %% [markdown]
# - Print out list of dictionary's keys
# - Print out list of dictionary's values

# %%
# Keys
print('Keys:', person.keys())

# Values
print('Values:', person.values())
# Out:
# Keys: dict_keys(['Name', 'Age', 'Job', 'Married'])
# Values: dict_values(['Bobby', 25, 'Teacher', 'Yes'])

# %% [markdown]
# - Change the job of Bobby to **Developer**

# %%
person['Job'] = 'Developer'
person
# Out:
# {'Name': 'Bobby', 'Age': 25, 'Job': 'Developer', 'Married': 'Yes'}

# %% [markdown]
# - Now, try to access an invalid key...

# %%
print(person['Hair color'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_518567/2236795187.py in <module>
# ----> 1 print(person['Hair color'])
#
# KeyError: 'Hair color'

# %% [markdown]
# Because the 'Hair color' is not declared in the dictionary so it will raise an error.
#
# To deal with this issue, use `get(key, default_value)` method to get the value of a key. If the key is not declared, it will return a `default_value`.
#
# Try again, get Bobby's hair color and return 'Unknown' for `default_value`.

# %%
person.get('Hair color', 'Unknown')
# Out:
# 'Unknown'

# %% [markdown]
# ## 1.5. Loop

# %% [markdown]
# Use a `for` loop to print out 9 multiplication tables (from 1 to 9), with each table separated by an empty line.
#
# Example format for a table with number 9:
# ```
# 9 x 1 = 9
# 9 x 2 = 18
# 9 x 3 = 27
# 9 x 4 = 36
# 9 x 5 = 45
# 9 x 6 = 54
# 9 x 7 = 63
# 9 x 8 = 72
# 9 x 9 = 81
# ```
# **Hint: use two nested loops**

# %%
for i in range(1, 10):
    for j in range(1, 10):
        print(f'{i} x {j} = {i*j}')
    print('\n')
# Out:
# 1 x 1 = 1
# 1 x 2 = 2
# 1 x 3 = 3
# 1 x 4 = 4
# 1 x 5 = 5
# 1 x 6 = 6
# 1 x 7 = 7
# 1 x 8 = 8
# 1 x 9 = 9
#
#
# 2 x 1 = 2
# 2 x 2 = 4
# 2 x 3 = 6
# 2 x 4 = 8
# 2 x 5 = 10
# 2 x 6 = 12
# 2 x 7 = 14
# 2 x 8 = 16
# 2 x 9 = 18
#
#
# 3 x 1 = 3
# 3 x 2 = 6
# 3 x 3 = 9
# 3 x 4 = 12
# 3 x 5 = 15
# 3 x 6 = 18
# 3 x 7 = 21
# 3 x 8 = 24
# 3 x 9 = 27
#
#
# 4 x 1 = 4
# 4 x 2 = 8
# 4 x 3 = 12
# 4 x 4 = 16
# 4 x 5 = 20
# 4 x 6 = 24
# 4 x 7 = 28
# 4 x 8 = 32
# 4 x 9 = 36
#
#
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
#
#
# 6 x 1 = 6
# 6 x 2 = 12
# 6 x 3 = 18
# 6 x 4 = 24
# 6 x 5 = 30
# 6 x 6 = 36
# 6 x 7 = 42
# 6 x 8 = 48
# 6 x 9 = 54
#
#
# 7 x 1 = 7
# 7 x 2 = 14
# 7 x 3 = 21
# 7 x 4 = 28
# 7 x 5 = 35
# 7 x 6 = 42
# 7 x 7 = 49
# 7 x 8 = 56
# 7 x 9 = 63
#
#
# 8 x 1 = 8
# 8 x 2 = 16
# 8 x 3 = 24
# 8 x 4 = 32
# 8 x 5 = 40
# 8 x 6 = 48
# 8 x 7 = 56
# 8 x 8 = 64
# 8 x 9 = 72
#
#
# 9 x 1 = 9
# 9 x 2 = 18
# 9 x 3 = 27
# 9 x 4 = 36
# 9 x 5 = 45
# 9 x 6 = 54
# 9 x 7 = 63
# 9 x 8 = 72
# 9 x 9 = 81

# %% [markdown]
# # 2. Advanced

# %% [markdown]
# ***Given a string s consisting of words and spaces, return the the last word and its length in the string.***
#
# ***A word is a maximal substring consisting of non-space characters only.***
#
# ***Output format: a string like `"[last word]:[length of last word]"`***
#
# **Example 1:**
#
# Input: s = "Hello World"
#
# Output: World:5
#
# Explanation: The last word is "World" with length 5.
#
# **Example 2:**
#
# Input: s = "   fly me   to   the moon  "
#
# Output: moon:4
#
# Explanation: The last word is "moon" with length 4.
#
# **Example 3:**
#
# Input: s = "luffy is still joyboy"
#
# Output: joyboy:6
#
# Explanation: The last word is "joyboy" with length 6.

# %%
def find_maximal_substring(s):
    word_arr = s.split(' ')
    for word in word_arr[::-1]:
        if word == '':
            continue
        
        last_word = word
        break
    
    return f'{last_word}:{len(last_word)}'

# %% [markdown]
# Now, test your function...

# %%
# Run this cell without modifying anything
str1 = "  Python  reads and  writes   very similarly to standard     English  "
print(find_maximal_substring(str1))
# Out:
# English:7
